# %% [markdown]
# # Maximum Likelihood Estimation (MLE)
#
# ## Introduction
#
# "Parameter Inference" is one of the most important concepts of predictive machine learning. In this lesson, you will begin to build an intuition surrounding the ideas around this concept. You'll first look at the maximum likelihood estimation (MLE) for the posterior probability based on observed data. (A direct application of Bayes theorem.) From there, you'll conduct a random experiment involving a series of coin tosses to derive the general formula for MLE of a binomial distribution.
#
# ## Objectives
#
# You will be able to:
#
# - Describe the process of parameter inference
# - Define likelihood and compare it to probability
# - List the two assumptions of Maximum Likelihood Estimation
# - Describe how Maximum Likelihood Estimation is related to parameter estimation
#
#
#
# ## Parameter Inference
#
# Parameter Inference is the process of probabilistically inferring parameter(s) for a model of our choice, that is which parameter values best describe the underlying dataset, used in an analytical context. Let's try to understand this with a simple experiment with a 10 times coin flip and inspecting the outcome.

# %%
import random
def coinToss():
    number = int(input("Number of times to flip coin: "))
    recordList = []
    heads = 0
    tails = 0
    for amount in range(number):
         flip = random.randint(0, 1)
         if (flip == 0):
              print("Toss", amount+1 ,':' , "Heads")
              recordList.append("Heads")
         else:
              print("Toss", amount+1 ,':' , "Tails")
              recordList.append("Tails")
    print(str(recordList))
    print(str(recordList.count("Heads")) + str(recordList.count("Tails")))
    return recordList

# %%
lst = coinToss()
# Out:
# Number of times to flip coin: 1000
# Toss 1 : Heads
# Toss 2 : Heads
# Toss 3 : Heads
# Toss 4 : Tails
# Toss 5 : Heads
# Toss 6 : Heads
# Toss 7 : Tails
# Toss 8 : Heads
# Toss 9 : Heads
# Toss 10 : Tails
# Toss 11 : Heads
# Toss 12 : Tails
# Toss 13 : Heads
# Toss 14 : Heads
# Toss 15 : Tails
# Toss 16 : Tails
# Toss 17 : Tails
# Toss 18 : Tails
# Toss 19 : Tails
# Toss 20 : Heads
# Toss 21 : Tails
# Toss 22 : Heads
# Toss 23 : Heads
# Toss 24 : Tails
# Toss 25 : Heads
# Toss 26 : Tails
# Toss 27 : Heads
# Toss 28 : Heads
# Toss 29 : Tails
# Toss 30 : Tails
# Toss 31 : Tails
# Toss 32 : Tails
# Toss 33 : Heads
# Toss 34 : Tails
# Toss 35 : Heads
# Toss 36 : Heads
# Toss 37 : Heads
# Toss 38 : Tails
# Toss 39 : Tails
# Toss 40 : Tails
# Toss 41 : Heads
# Toss 42 : Heads
# Toss 43 : Heads
# Toss 44 : Tails
# Toss 45 : Tails
# Toss 46 : Tails
# Toss 47 : Heads
# Toss 48 : Heads
# Toss 49 : Tails
# Toss 50 : Heads
# Toss 51 : Tails
# Toss 52 : Tails
# Toss 53 : Heads
# Toss 54 : Heads
# Toss 55 : Heads
# Toss 56 : Tails
# Toss 57 : Tails
# Toss 58 : Tails
# Toss 59 : Tails
# Toss 60 : Tails
# Toss 61 : Tails
# Toss 62 : Heads
# Toss 63 : Tails
# Toss 64 : Heads
# Toss 65 : Heads
# Toss 66 : Heads
# Toss 67 : Heads
# Toss 68 : Tails
# Toss 69 : Heads
# Toss 70 : Heads
# Toss 71 : Heads
# Toss 72 : Tails
# Toss 73 : Tails
# Toss 74 : Tails
# Toss 75 : Heads
# Toss 76 : Tails
# Toss 77 : Heads
# Toss 78 : Tails
# Toss 79 : Tails
# Toss 80 : Heads
# Toss 81 : Heads
# Toss 82 : Heads
# Toss 83 : Heads
# Toss 84 : Heads
# Toss 85 : Heads
# Toss 86 : Heads
# Toss 87 : Heads
# Toss 88 : Heads
# Toss 89 : Tails
# Toss 90 : Tails
# Toss 91 : Heads
# Toss 92 : Tails
# Toss 93 : Tails
# Toss 94 : Tails
# Toss 95 : Tails
# Toss 96 : Tails
# Toss 97 : Tails
# Toss 98 : Heads
# Toss 99 : Tails
# Toss 100 : Heads
# Toss 101 : Heads
# Toss 102 : Heads
# Toss 103 : Heads
# Toss 104 : Tails
# Toss 105 : Tails
# Toss 106 : Heads
# Toss 107 : Tails
# Toss 108 : Tails
# Toss 109 : Tails
# Toss 110 : Tails
# Toss 111 : Tails
# Toss 112 : Tails
# Toss 113 : Tails
# Toss 114 : Heads
# Toss 115 : Heads
# Toss 116 : Tails
# Toss 117 : Tails
# Toss 118 : Heads
# Toss 119 : Tails
# Toss 120 : Tails
# Toss 121 : Tails
# Toss 122 : Heads
# Toss 123 : Tails
# Toss 124 : Heads
# Toss 125 : Tails
# Toss 126 : Tails
# Toss 127 : Heads
# Toss 128 : Tails
# Toss 129 : Tails
# Toss 130 : Heads
# Toss 131 : Heads
# Toss 132 : Tails
# Toss 133 : Tails
# Toss 134 : Tails
# Toss 135 : Heads
# Toss 136 : Tails
# Toss 137 : Heads
# Toss 138 : Tails
# Toss 139 : Tails
# Toss 140 : Heads
# Toss 141 : Tails
# Toss 142 : Tails
# Toss 143 : Tails
# Toss 144 : Tails
# Toss 145 : Heads
# Toss 146 : Tails
# Toss 147 : Heads
# Toss 148 : Tails
# Toss 149 : Heads
# Toss 150 : Heads
# Toss 151 : Heads
# Toss 152 : Tails
# Toss 153 : Heads
# Toss 154 : Tails
# Toss 155 : Heads
# Toss 156 : Tails
# Toss 157 : Tails
# Toss 158 : Tails
# Toss 159 : Heads
# Toss 160 : Heads
# Toss 161 : Heads
# Toss 162 : Tails
# Toss 163 : Heads
# Toss 164 : Tails
# Toss 165 : Heads
# Toss 166 : Tails
# Toss 167 : Tails
# Toss 168 : Tails
# Toss 169 : Tails
# Toss 170 : Heads
# Toss 171 : Heads
# Toss 172 : Tails
# Toss 173 : Tails
# Toss 174 : Heads
# Toss 175 : Tails
# Toss 176 : Heads
# Toss 177 : Tails
# Toss 178 : Heads
# Toss 179 : Heads
# Toss 180 : Heads
# Toss 181 : Heads
# Toss 182 : Tails
# Toss 183 : Tails
# Toss 184 : Heads
# Toss 185 : Tails
# Toss 186 : Tails
# Toss 187 : Tails
# Toss 188 : Tails
# Toss 189 : Heads
# Toss 190 : Heads
# Toss 191 : Tails
# Toss 192 : Heads
# Toss 193 : Tails
# Toss 194 : Tails
# Toss 195 : Tails
# Toss 196 : Tails
# Toss 197 : Heads
# Toss 198 : Tails
# Toss 199 : Tails
# Toss 200 : Tails
# Toss 201 : Heads
# Toss 202 : Heads
# Toss 203 : Heads
# Toss 204 : Heads
# Toss 205 : Tails
# Toss 206 : Heads
# Toss 207 : Tails
# Toss 208 : Tails
# Toss 209 : Heads
# Toss 210 : Tails
# Toss 211 : Heads
# Toss 212 : Tails
# Toss 213 : Heads
# Toss 214 : Heads
# Toss 215 : Tails
# Toss 216 : Heads
# Toss 217 : Heads
# Toss 218 : Tails
# Toss 219 : Tails
# Toss 220 : Heads
# Toss 221 : Heads
# Toss 222 : Tails
# Toss 223 : Tails
# Toss 224 : Tails
# Toss 225 : Heads
# Toss 226 : Heads
# Toss 227 : Tails
# Toss 228 : Tails
# Toss 229 : Tails
# Toss 230 : Heads
# Toss 231 : Heads
# Toss 232 : Heads
# Toss 233 : Heads
# Toss 234 : Tails
# Toss 235 : Heads
# Toss 236 : Heads
# Toss 237 : Heads
# Toss 238 : Heads
# Toss 239 : Heads
# Toss 240 : Tails
# Toss 241 : Tails
# Toss 242 : Heads
# Toss 243 : Heads
# Toss 244 : Tails
# Toss 245 : Heads
# Toss 246 : Tails
# Toss 247 : Tails
# Toss 248 : Tails
# Toss 249 : Tails
# Toss 250 : Tails
# Toss 251 : Tails
# Toss 252 : Heads
# Toss 253 : Tails
# Toss 254 : Tails
# Toss 255 : Heads
# Toss 256 : Heads
# Toss 257 : Heads
# Toss 258 : Tails
# Toss 259 : Heads
# Toss 260 : Tails
# Toss 261 : Heads
# Toss 262 : Heads
# Toss 263 : Heads
# Toss 264 : Tails
# Toss 265 : Heads
# Toss 266 : Tails
# Toss 267 : Tails
# Toss 268 : Heads
# Toss 269 : Tails
# Toss 270 : Tails
# Toss 271 : Tails
# Toss 272 : Tails
# Toss 273 : Tails
# Toss 274 : Heads
# Toss 275 : Heads
# Toss 276 : Tails
# Toss 277 : Heads
# Toss 278 : Tails
# Toss 279 : Tails
# Toss 280 : Tails
# Toss 281 : Tails
# Toss 282 : Tails
# Toss 283 : Tails
# Toss 284 : Heads
# Toss 285 : Tails
# Toss 286 : Tails
# Toss 287 : Heads
# Toss 288 : Heads
# Toss 289 : Heads
# Toss 290 : Heads
# Toss 291 : Heads
# Toss 292 : Tails
# Toss 293 : Tails
# Toss 294 : Tails
# Toss 295 : Tails
# Toss 296 : Tails
# Toss 297 : Heads
# Toss 298 : Tails
# Toss 299 : Heads
# Toss 300 : Tails
# Toss 301 : Heads
# Toss 302 : Heads
# Toss 303 : Heads
# Toss 304 : Tails
# Toss 305 : Heads
# Toss 306 : Tails
# Toss 307 : Tails
# Toss 308 : Heads
# Toss 309 : Tails
# Toss 310 : Heads
# Toss 311 : Heads
# Toss 312 : Heads
# Toss 313 : Tails
# Toss 314 : Heads
# Toss 315 : Heads
# Toss 316 : Tails
# Toss 317 : Tails
# Toss 318 : Tails
# Toss 319 : Tails
# Toss 320 : Tails
# Toss 321 : Tails
# Toss 322 : Heads
# Toss 323 : Heads
# Toss 324 : Tails
# Toss 325 : Tails
# Toss 326 : Heads
# Toss 327 : Heads
# Toss 328 : Tails
# Toss 329 : Tails
# Toss 330 : Tails
# Toss 331 : Heads
# Toss 332 : Heads
# Toss 333 : Heads
# Toss 334 : Tails
# Toss 335 : Tails
# Toss 336 : Tails
# Toss 337 : Heads
# Toss 338 : Tails
# Toss 339 : Heads
# Toss 340 : Heads
# Toss 341 : Tails
# Toss 342 : Heads
# Toss 343 : Heads
# Toss 344 : Tails
# Toss 345 : Tails
# Toss 346 : Tails
# Toss 347 : Tails
# Toss 348 : Heads
# Toss 349 : Heads
# Toss 350 : Heads
# Toss 351 : Heads
# Toss 352 : Tails
# Toss 353 : Tails
# Toss 354 : Tails
# Toss 355 : Tails
# Toss 356 : Heads
# Toss 357 : Heads
# Toss 358 : Heads
# Toss 359 : Heads
# Toss 360 : Tails
# Toss 361 : Heads
# Toss 362 : Heads
# Toss 363 : Heads
# Toss 364 : Heads
# Toss 365 : Heads
# Toss 366 : Tails
# Toss 367 : Heads
# Toss 368 : Heads
# Toss 369 : Tails
# Toss 370 : Heads
# Toss 371 : Heads
# Toss 372 : Heads
# Toss 373 : Tails
# Toss 374 : Tails
# Toss 375 : Heads
# Toss 376 : Tails
# Toss 377 : Tails
# Toss 378 : Tails
# Toss 379 : Heads
# Toss 380 : Heads
# Toss 381 : Tails
# Toss 382 : Heads
# Toss 383 : Tails
# Toss 384 : Tails
# Toss 385 : Heads
# Toss 386 : Heads
# Toss 387 : Heads
# Toss 388 : Heads
# Toss 389 : Heads
# Toss 390 : Heads
# Toss 391 : Tails
# Toss 392 : Heads
# Toss 393 : Tails
# Toss 394 : Tails
# Toss 395 : Tails
# Toss 396 : Heads
# Toss 397 : Heads
# Toss 398 : Tails
# Toss 399 : Tails
# Toss 400 : Heads
# Toss 401 : Heads
# Toss 402 : Tails
# Toss 403 : Heads
# Toss 404 : Tails
# Toss 405 : Tails
# Toss 406 : Heads
# Toss 407 : Tails
# Toss 408 : Tails
# Toss 409 : Heads
# Toss 410 : Heads
# Toss 411 : Heads
# Toss 412 : Heads
# Toss 413 : Tails
# Toss 414 : Tails
# Toss 415 : Tails
# Toss 416 : Tails
# Toss 417 : Heads
# Toss 418 : Heads
# Toss 419 : Tails
# Toss 420 : Heads
# Toss 421 : Heads
# Toss 422 : Tails
# Toss 423 : Heads
# Toss 424 : Heads
# Toss 425 : Heads
# Toss 426 : Tails
# Toss 427 : Heads
# Toss 428 : Heads
# Toss 429 : Heads
# Toss 430 : Heads
# Toss 431 : Tails
# Toss 432 : Heads
# Toss 433 : Tails
# Toss 434 : Heads
# Toss 435 : Tails
# Toss 436 : Heads
# Toss 437 : Heads
# Toss 438 : Heads
# Toss 439 : Heads
# Toss 440 : Heads
# Toss 441 : Heads
# Toss 442 : Tails
# Toss 443 : Heads
# Toss 444 : Tails
# Toss 445 : Heads
# Toss 446 : Tails
# Toss 447 : Heads
# Toss 448 : Heads
# Toss 449 : Heads
# Toss 450 : Tails
# Toss 451 : Heads
# Toss 452 : Tails
# Toss 453 : Heads
# Toss 454 : Heads
# Toss 455 : Tails
# Toss 456 : Heads
# Toss 457 : Tails
# Toss 458 : Heads
# Toss 459 : Heads
# Toss 460 : Heads
# Toss 461 : Heads
# Toss 462 : Heads
# Toss 463 : Heads
# Toss 464 : Tails
# Toss 465 : Heads
# Toss 466 : Tails
# Toss 467 : Heads
# Toss 468 : Heads
# Toss 469 : Heads
# Toss 470 : Tails
# Toss 471 : Tails
# Toss 472 : Heads
# Toss 473 : Tails
# Toss 474 : Heads
# Toss 475 : Heads
# Toss 476 : Tails
# Toss 477 : Tails
# Toss 478 : Heads
# Toss 479 : Tails
# Toss 480 : Tails
# Toss 481 : Tails
# Toss 482 : Heads
# Toss 483 : Tails
# Toss 484 : Heads
# Toss 485 : Heads
# Toss 486 : Tails
# Toss 487 : Heads
# Toss 488 : Tails
# Toss 489 : Heads
# Toss 490 : Tails
# Toss 491 : Heads
# Toss 492 : Heads
# Toss 493 : Heads
# Toss 494 : Tails
# Toss 495 : Heads
# Toss 496 : Heads
# Toss 497 : Heads
# Toss 498 : Heads
# Toss 499 : Heads
# Toss 500 : Heads
# Toss 501 : Heads
# Toss 502 : Tails
# Toss 503 : Heads
# Toss 504 : Tails
# Toss 505 : Tails
# Toss 506 : Tails
# Toss 507 : Heads
# Toss 508 : Heads
# Toss 509 : Heads
# Toss 510 : Heads
# Toss 511 : Tails
# Toss 512 : Heads
# Toss 513 : Heads
# Toss 514 : Heads
# Toss 515 : Tails
# Toss 516 : Tails
# Toss 517 : Tails
# Toss 518 : Tails
# Toss 519 : Heads
# Toss 520 : Tails
# Toss 521 : Tails
# Toss 522 : Tails
# Toss 523 : Heads
# Toss 524 : Tails
# Toss 525 : Tails
# Toss 526 : Heads
# Toss 527 : Tails
# Toss 528 : Heads
# Toss 529 : Tails
# Toss 530 : Heads
# Toss 531 : Heads
# Toss 532 : Heads
# Toss 533 : Tails
# Toss 534 : Heads
# Toss 535 : Tails
# Toss 536 : Tails
# Toss 537 : Tails
# Toss 538 : Tails
# Toss 539 : Tails
# Toss 540 : Heads
# Toss 541 : Heads
# Toss 542 : Heads
# Toss 543 : Tails
# Toss 544 : Tails
# Toss 545 : Tails
# Toss 546 : Tails
# Toss 547 : Tails
# Toss 548 : Heads
# Toss 549 : Tails
# Toss 550 : Tails
# Toss 551 : Heads
# Toss 552 : Heads
# Toss 553 : Heads
# Toss 554 : Heads
# Toss 555 : Tails
# Toss 556 : Heads
# Toss 557 : Heads
# Toss 558 : Tails
# Toss 559 : Tails
# Toss 560 : Heads
# Toss 561 : Heads
# Toss 562 : Heads
# Toss 563 : Heads
# Toss 564 : Heads
# Toss 565 : Heads
# Toss 566 : Heads
# Toss 567 : Tails
# Toss 568 : Heads
# Toss 569 : Tails
# Toss 570 : Tails
# Toss 571 : Heads
# Toss 572 : Heads
# Toss 573 : Tails
# Toss 574 : Tails
# Toss 575 : Tails
# Toss 576 : Heads
# Toss 577 : Tails
# Toss 578 : Tails
# Toss 579 : Tails
# Toss 580 : Heads
# Toss 581 : Tails
# Toss 582 : Tails
# Toss 583 : Tails
# Toss 584 : Heads
# Toss 585 : Heads
# Toss 586 : Heads
# Toss 587 : Tails
# Toss 588 : Tails
# Toss 589 : Tails
# Toss 590 : Tails
# Toss 591 : Tails
# Toss 592 : Tails
# Toss 593 : Heads
# Toss 594 : Heads
# Toss 595 : Tails
# Toss 596 : Tails
# Toss 597 : Tails
# Toss 598 : Tails
# Toss 599 : Heads
# Toss 600 : Heads
# Toss 601 : Tails
# Toss 602 : Heads
# Toss 603 : Heads
# Toss 604 : Tails
# Toss 605 : Heads
# Toss 606 : Heads
# Toss 607 : Tails
# Toss 608 : Heads
# Toss 609 : Tails
# Toss 610 : Heads
# Toss 611 : Tails
# Toss 612 : Tails
# Toss 613 : Heads
# Toss 614 : Tails
# Toss 615 : Heads
# Toss 616 : Tails
# Toss 617 : Heads
# Toss 618 : Heads
# Toss 619 : Heads
# Toss 620 : Tails
# Toss 621 : Tails
# Toss 622 : Heads
# Toss 623 : Heads
# Toss 624 : Tails
# Toss 625 : Heads
# Toss 626 : Heads
# Toss 627 : Tails
# Toss 628 : Tails
# Toss 629 : Tails
# Toss 630 : Heads
# Toss 631 : Tails
# Toss 632 : Tails
# Toss 633 : Heads
# Toss 634 : Tails
# Toss 635 : Tails
# Toss 636 : Heads
# Toss 637 : Tails
# Toss 638 : Tails
# Toss 639 : Tails
# Toss 640 : Tails
# Toss 641 : Tails
# Toss 642 : Tails
# Toss 643 : Heads
# Toss 644 : Tails
# Toss 645 : Tails
# Toss 646 : Tails
# Toss 647 : Heads
# Toss 648 : Tails
# Toss 649 : Tails
# Toss 650 : Tails
# Toss 651 : Tails
# Toss 652 : Tails
# Toss 653 : Heads
# Toss 654 : Tails
# Toss 655 : Tails
# Toss 656 : Heads
# Toss 657 : Tails
# Toss 658 : Heads
# Toss 659 : Heads
# Toss 660 : Heads
# Toss 661 : Tails
# Toss 662 : Heads
# Toss 663 : Heads
# Toss 664 : Tails
# Toss 665 : Tails
# Toss 666 : Tails
# Toss 667 : Tails
# Toss 668 : Tails
# Toss 669 : Heads
# Toss 670 : Tails
# Toss 671 : Heads
# Toss 672 : Heads
# Toss 673 : Heads
# Toss 674 : Tails
# Toss 675 : Tails
# Toss 676 : Tails
# Toss 677 : Tails
# Toss 678 : Tails
# Toss 679 : Heads
# Toss 680 : Heads
# Toss 681 : Tails
# Toss 682 : Tails
# Toss 683 : Heads
# Toss 684 : Heads
# Toss 685 : Heads
# Toss 686 : Heads
# Toss 687 : Tails
# Toss 688 : Tails
# Toss 689 : Heads
# Toss 690 : Heads
# Toss 691 : Tails
# Toss 692 : Tails
# Toss 693 : Heads
# Toss 694 : Tails
# Toss 695 : Heads
# Toss 696 : Tails
# Toss 697 : Heads
# Toss 698 : Tails
# Toss 699 : Tails
# Toss 700 : Tails
# Toss 701 : Heads
# Toss 702 : Heads
# Toss 703 : Heads
# Toss 704 : Heads
# Toss 705 : Tails
# Toss 706 : Heads
# Toss 707 : Heads
# Toss 708 : Tails
# Toss 709 : Heads
# Toss 710 : Heads
# Toss 711 : Heads
# Toss 712 : Tails
# Toss 713 : Heads
# Toss 714 : Tails
# Toss 715 : Heads
# Toss 716 : Tails
# Toss 717 : Tails
# Toss 718 : Heads
# Toss 719 : Heads
# Toss 720 : Heads
# Toss 721 : Tails
# Toss 722 : Heads
# Toss 723 : Heads
# Toss 724 : Heads
# Toss 725 : Heads
# Toss 726 : Tails
# Toss 727 : Tails
# Toss 728 : Tails
# Toss 729 : Tails
# Toss 730 : Heads
# Toss 731 : Tails
# Toss 732 : Tails
# Toss 733 : Tails
# Toss 734 : Heads
# Toss 735 : Heads
# Toss 736 : Tails
# Toss 737 : Tails
# Toss 738 : Tails
# Toss 739 : Heads
# Toss 740 : Tails
# Toss 741 : Heads
# Toss 742 : Tails
# Toss 743 : Tails
# Toss 744 : Tails
# Toss 745 : Heads
# Toss 746 : Heads
# Toss 747 : Tails
# Toss 748 : Heads
# Toss 749 : Heads
# Toss 750 : Heads
# Toss 751 : Tails
# Toss 752 : Tails
# Toss 753 : Tails
# Toss 754 : Tails
# Toss 755 : Tails
# Toss 756 : Tails
# Toss 757 : Heads
# Toss 758 : Heads
# Toss 759 : Tails
# Toss 760 : Heads
# Toss 761 : Heads
# Toss 762 : Heads
# Toss 763 : Heads
# Toss 764 : Tails
# Toss 765 : Heads
# Toss 766 : Heads
# Toss 767 : Heads
# Toss 768 : Tails
# Toss 769 : Tails
# Toss 770 : Heads
# Toss 771 : Heads
# Toss 772 : Heads
# Toss 773 : Tails
# Toss 774 : Heads
# Toss 775 : Tails
# Toss 776 : Heads
# Toss 777 : Tails
# Toss 778 : Heads
# Toss 779 : Tails
# Toss 780 : Heads
# Toss 781 : Tails
# Toss 782 : Heads
# Toss 783 : Tails
# Toss 784 : Heads
# Toss 785 : Tails
# Toss 786 : Tails
# Toss 787 : Heads
# Toss 788 : Heads
# Toss 789 : Tails
# Toss 790 : Tails
# Toss 791 : Tails
# Toss 792 : Heads
# Toss 793 : Tails
# Toss 794 : Heads
# Toss 795 : Tails
# Toss 796 : Heads
# Toss 797 : Heads
# Toss 798 : Heads
# Toss 799 : Heads
# Toss 800 : Heads
# Toss 801 : Tails
# Toss 802 : Tails
# Toss 803 : Tails
# Toss 804 : Heads
# Toss 805 : Tails
# Toss 806 : Heads
# Toss 807 : Heads
# Toss 808 : Tails
# Toss 809 : Tails
# Toss 810 : Tails
# Toss 811 : Heads
# Toss 812 : Tails
# Toss 813 : Tails
# Toss 814 : Tails
# Toss 815 : Tails
# Toss 816 : Tails
# Toss 817 : Tails
# Toss 818 : Heads
# Toss 819 : Heads
# Toss 820 : Heads
# Toss 821 : Heads
# Toss 822 : Tails
# Toss 823 : Heads
# Toss 824 : Heads
# Toss 825 : Tails
# Toss 826 : Heads
# Toss 827 : Heads
# Toss 828 : Heads
# Toss 829 : Heads
# Toss 830 : Tails
# Toss 831 : Tails
# Toss 832 : Heads
# Toss 833 : Tails
# Toss 834 : Heads
# Toss 835 : Heads
# Toss 836 : Heads
# Toss 837 : Heads
# Toss 838 : Heads
# Toss 839 : Tails
# Toss 840 : Tails
# Toss 841 : Tails
# Toss 842 : Tails
# Toss 843 : Heads
# Toss 844 : Heads
# Toss 845 : Heads
# Toss 846 : Heads
# Toss 847 : Heads
# Toss 848 : Heads
# Toss 849 : Tails
# Toss 850 : Heads
# Toss 851 : Heads
# Toss 852 : Tails
# Toss 853 : Tails
# Toss 854 : Tails
# Toss 855 : Heads
# Toss 856 : Heads
# Toss 857 : Heads
# Toss 858 : Tails
# Toss 859 : Heads
# Toss 860 : Tails
# Toss 861 : Tails
# Toss 862 : Tails
# Toss 863 : Heads
# Toss 864 : Tails
# Toss 865 : Tails
# Toss 866 : Heads
# Toss 867 : Tails
# Toss 868 : Tails
# Toss 869 : Heads
# Toss 870 : Tails
# Toss 871 : Tails
# Toss 872 : Heads
# Toss 873 : Tails
# Toss 874 : Tails
# Toss 875 : Tails
# Toss 876 : Heads
# Toss 877 : Tails
# Toss 878 : Heads
# Toss 879 : Heads
# Toss 880 : Tails
# Toss 881 : Heads
# Toss 882 : Heads
# Toss 883 : Tails
# Toss 884 : Tails
# Toss 885 : Tails
# Toss 886 : Tails
# Toss 887 : Heads
# Toss 888 : Heads
# Toss 889 : Tails
# Toss 890 : Tails
# Toss 891 : Heads
# Toss 892 : Tails
# Toss 893 : Heads
# Toss 894 : Heads
# Toss 895 : Tails
# Toss 896 : Heads
# Toss 897 : Tails
# Toss 898 : Tails
# Toss 899 : Tails
# Toss 900 : Heads
# Toss 901 : Heads
# Toss 902 : Heads
# Toss 903 : Heads
# Toss 904 : Heads
# Toss 905 : Tails
# Toss 906 : Tails
# Toss 907 : Heads
# Toss 908 : Heads
# Toss 909 : Heads
# Toss 910 : Heads
# Toss 911 : Heads
# Toss 912 : Tails
# Toss 913 : Heads
# Toss 914 : Tails
# Toss 915 : Tails
# Toss 916 : Tails
# Toss 917 : Tails
# Toss 918 : Tails
# Toss 919 : Tails
# Toss 920 : Heads
# Toss 921 : Tails
# Toss 922 : Heads
# Toss 923 : Tails
# Toss 924 : Heads
# Toss 925 : Heads
# Toss 926 : Heads
# Toss 927 : Heads
# Toss 928 : Heads
# Toss 929 : Heads
# Toss 930 : Tails
# Toss 931 : Tails
# Toss 932 : Heads
# Toss 933 : Tails
# Toss 934 : Heads
# Toss 935 : Tails
# Toss 936 : Tails
# Toss 937 : Heads
# Toss 938 : Tails
# Toss 939 : Tails
# Toss 940 : Heads
# Toss 941 : Heads
# Toss 942 : Tails
# Toss 943 : Heads
# Toss 944 : Heads
# Toss 945 : Heads
# Toss 946 : Tails
# Toss 947 : Heads
# Toss 948 : Heads
# Toss 949 : Heads
# Toss 950 : Heads
# Toss 951 : Heads
# Toss 952 : Tails
# Toss 953 : Heads
# Toss 954 : Tails
# Toss 955 : Heads
# Toss 956 : Heads
# Toss 957 : Tails
# Toss 958 : Heads
# Toss 959 : Tails
# Toss 960 : Tails
# Toss 961 : Heads
# Toss 962 : Tails
# Toss 963 : Heads
# Toss 964 : Tails
# Toss 965 : Heads
# Toss 966 : Heads
# Toss 967 : Tails
# Toss 968 : Heads
# Toss 969 : Tails
# Toss 970 : Tails
# Toss 971 : Tails
# Toss 972 : Tails
# Toss 973 : Heads
# Toss 974 : Heads
# Toss 975 : Heads
# Toss 976 : Heads
# Toss 977 : Tails
# Toss 978 : Tails
# Toss 979 : Heads
# Toss 980 : Tails
# Toss 981 : Heads
# Toss 982 : Tails
# Toss 983 : Heads
# Toss 984 : Heads
# Toss 985 : Heads
# Toss 986 : Tails
# Toss 987 : Heads
# Toss 988 : Heads
# Toss 989 : Tails
# Toss 990 : Tails
# Toss 991 : Tails
# Toss 992 : Heads
# Toss 993 : Heads
# Toss 994 : Tails
# Toss 995 : Tails
# Toss 996 : Heads
# Toss 997 : Heads
# Toss 998 : Tails
# Toss 999 : Tails
# Toss 1000 : Tails
# ['Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'He ...
# 502498

# %% [markdown]
# Remember its a random experiment so the output will change everytime you run it. Here is the output sequence we'll use in this lesson:
# ```
# ['Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads']
# ```
# Considering its a random experiment, you can say that there has to be *some* underlying parameter for the outcome of a coin flip. Also, consider other random experiments with dice rolls. Can you identify a parameter that determines the outcome of such experiments?
#
# Parameter Inference is all to do with identifying that parameter with its optimal value. The first key step in this process is Maximum Likelihood Estimation (MLE).

# %% [markdown]
# ## Maximum Likelihood Estimation
#
# MLE primarily deals with **determining the parameters** that **maximize the probability of the data**. Such a determination can help you predict the outcome of future experiments, e.g., if we toss the coin 1 more time, what is the probability of seeing a head?
#
# * It's a fair coin so the probability is 0.5
#
# This is a safe assumption as it assumes independence between coin flips and hence past events have no impact on future ones.

# %%
p_head = lst.count('Heads')/10
p_head
# Out:
# 50.2

# %% [markdown]
# With both these approaches in hand, let's see which answer is more suitable by creating a general case from this example. You want to know the probability of 11th flip $ p_{11}(f_{11})$, being a head so you can write:
#
# > $p_{11}(f_{11}= \text{Heads})$
#
# You can also write above for calculating the probability of $ith$ flip being a head:
#
# > $p_i(f_i = \text{Heads}) = \theta_i$

# %% [markdown]
# Here $\theta_i$ is the parameter that governs the outcome of _ith_ flip. To signify that the probability distribution depends on $\theta_i$, you can use conditioning as you saw earlier and write down the last equation to show the probability distribution function along with its dependence on $\text{theta_i}$.
#
# > $p_i((f_i = Heads) | \theta_i)$
#
# *The probability of seeing heads in the ith flip , given theta_i*

# %% [markdown]
# This makes sense so far, but raises a few confusing points: If the data depends on theta parameter, then the first ten coin flips f_1 to f_10 depend on theta_1 to theta_10  for i = 1 to 10. So looking at the outcome of first ten experiments, how can we extrapolate it to theta_11?
#
#
# Here's how you can do this&mdash;if you say that random outcome of a sequence of flips is governed (or modeled) by the parameters theta_1 to theta_10, you can calculate the probability function based on observed data as:
#
# > $P (Heads, Heads, Tails, Tails, Tails, Heads, Tails, Heads, Heads, Heads) | \theta_{1}\theta_{2} .. \theta_{10})$

# %% [markdown]
# This is where Maximum Likelihood Estimation steps into the equation. The problem you have now is that you need to find values of thetas 1 to 10.  MLE helps find theta_i’s such that that probability function shown above is **as high as possible** and this is the basic principle of MLE.

# %% [markdown]
# #### Likelihood - The probability of data
#
# MLE looks at the probability of data and it tries to find those parameters (i.e. theta_1 through theta_10 in above case) that maximize the likelihood of this sequence occurring.
#
# > With maximum liklihood estimation, we want to choose those parameters under which our observations become most **likely**.

# %% [markdown]
# Going back to our coin flip example. If in our understanding, the coin flips do not affect each other, i.e., they are independent (the outcome of first flip does not affect the outcome of the second flip):
# >$P (H, H, T, T, T, H, T, H, H, H) | \theta_{1}\theta_{2} .. \theta_{10})$
#
# >$= P(F_1 = H | \theta_1).P(F_2 = H | \theta_2) .. P(F_{10} = H | \theta_{10})$
#
# >$= \prod_{i=1}^{10} p_i(F_i = f_i | \theta_i)$ - The general case for coin flip
#
# Note: $\prod$ signifies the product over a series, shown in the previous equation, just as $\Sigma$ denotes summation over a series.

# %% [markdown]
# ### MLE assumptions
#
# Note here that the **independence assumption** allows you to simplify the complex likelihood term into ten simpler factors that can be shown through a general notation in the last equation.
#
# The independence assumption allows simplification of the likelihood term but you still don’t have theta_11 in the equation.
#
# There is another assumption you can introduce, based on the fact that the coin does not change significantly after each flip i.e.:
#
# * **The flips are quantitatively same, i.e., they are identically distributed**.
#
# This implies that the flips are taking place under similar circumstances, you can assume that the parameter governing the flips is one and same i.e. just the $\theta$ without any subscripts. Based on this assumption, you can rewrite above equation as :

# %% [markdown]
# >$\prod_{i=1}^{10} p_i(F_i = f_i | \theta_i) = \prod_{i=1}^{10} p(F_i = f_i | \theta) $

# %% [markdown]
# This assumption leads you to believe that the 10 flips are governed by the same parameter theta. You now have just one parameter governing the entire sequence of coin flips, and that includes the 11th flip as well.
#
# This is how MLE allows you to connect first 10 coin flips to the 11th coin flip and is the key for inference.

# %% [markdown]
# > The two assumptions you made are used so often in Machine Learning that they have a special name together as an entity : "The i.i.d. assumption" i.e. Independent and Identically distributed samples.

# %% [markdown]
# This means that the 10 flips are independent and identically distributed which is great as it will allow you to explicitly write down the likelihood that you are trying to optimize.
#
# Remember that theta was defined as the probability of the flip showing up heads; the probability of the sequence w.r.t. theta can now be formulated as:

# %% [markdown]
# $ \prod_{i=1}^{10} p(F_i = f_i | \theta)$
#
# $= \theta \theta (1-\theta)(1-\theta)(1-\theta) \theta(1-\theta)\theta\theta\theta$
#
# $=\theta^6(1-\theta)^4$
#
# * theta = Probability of seeing a head
# * 1 - theta = Probability of seeing a tail
# * The sequence:  H, H, T, T, T, H, T, H, H, H

# %% [markdown]
# You see here the i.i.d. assumptions simplifies  the likelihood function to a simple polynomial; to a point where you can **start optimizing the function for the parameter theta**.

# %% [markdown]
# This simplified polynomial expression can be interpreted as a function of theta i.e.,
# > $f(\theta)$
#
# Now you want to find out the maxima (maximum likelihood) of this function.
#
# <img src="images/der.png" width= "200">
#
#
# Following the intuition in the image above, you can achieve this theta by taking the derivative
# > $\frac{df}{d(\theta)}$
#
# Set this  zero, and solve for theta. Then verify the critical point i.e. maxima, by inserting it into the second derivative of $f(\theta)$. This is a simple approach, however, the application of product rule repeatedly in this process could be a technically challenging process. This calculation can be simplified using a monotonic function.
#
#
# ### Monotonic function
#
# > In mathematics, a [monotonic function](https://en.wikipedia.org/wiki/Monotonic_function) (or monotone function) is a function between ordered sets that preserves or reverses the given order. This concept first arose in calculus, and was later generalized to the more abstract setting of order theory.
#
#
# According to this theory, if you apply a monotonic function to another function, like the one you are trying to optimize above, this application will preserve the critical points (maxima in this case) of the original function. Logarithmic functions are normally used within the domain of machine learning to achieve the functionality of monotonicity. The logarithmic function is described as:
#
# > $log_b(x)$
#
# * where b is any number such that b > 0, b ≠ 1, and x > 0
# * The function is read "log base b of x"
#
# The logarithm y is the exponent to which b must be raised to get x. The behavior of a log function can be understood from following image.
#
#
# <img src="images/new_log.png" width="700">
#
#
# This helps you realize that **log of f(θ) i.e. log(f(θ)) will have the save maxima as the likelihood function f(θ).** This is better known as the **log likelihood**.
#
# Thus, the optimization function i.e. $\theta^6(1-\theta)^4$ , that you're trying to optimize w.r.t. theta can be written down as:
#
# > $\underset{\theta}{\operatorname{argmax}} \theta^6(1-\theta)^4$
#
# > In mathematics, the arguments of the maxima (abbreviated arg max or argmax) are the points of the domain of some function at which the function values are maximized.
#
# Remember that you are not concerned with the actual maximum value of the function. You want to **learn the value for theta** where the **function has the maximum value**.
#
# Following the monotonicity principle, the argmax function can be written with natural log *ln* as:
#
# > $\underset{\theta}{\operatorname{argmax}} ln(\theta^6(1-\theta)^4)$
#
# > $=\underset{\theta}{\operatorname{argmax}} 6 (ln (\theta)) + 4 (ln(1-\theta))$
#
# Let's call our log likelihood function $g(\theta)$, take its derivative and set it to zero.

# %% [markdown]
# > $ \frac{d}{d\theta}[g(\theta)] = |H|\frac{1}{\theta} + |T|\frac{1}{1-\theta}(-1)$
#
# |T| are the number of tails = 4
# |H| are the number of heads = 6
#
# You are simply solving for a general case here , so use |T| and |H|

# %% [markdown]
# > $|H|\frac{1}{\theta} + {|T|}\frac{1}{1-\theta}(-1) = 0 $

# %% [markdown]
# > $|H|(1-\theta) - |T|\theta = 0$
#
# > $\theta = \frac{|H|}{|H|+ |T|}$

# %% [markdown]
# This is the Maximum Likelihood Function $\theta_MLE$ for any given sequence of coins.
#
# $$\theta_{MLE} = \frac{|H|}{|H|+ |T|}$$
#
# For the initial problem, where H = 6  and T = 4, you get MLE for theta as 6/10 = 0.6 , or , 60% chance of seeing a head for the 11th coin given the data from first 10 coin flips.

# %% [markdown]
# > This maximum is called the **MLE for theta** as it makes the observed sequence **most likely**.

# %% [markdown]
# ## Limitations of MLE
#
# Consider a scenario where you get this sequence by total chance: [T, T, T, T, T]. According to the derived MLE formula, the probability of seeing a head at 6th coin toss would be zero. This demonstrates how MLE heavily depends on past data to find the likelihood function. It also indicates that MLE is only a first step for parameter estimation. We shall come across more sophisticated approaches like Maximum Aposteriori Estimate (MAP) and Fully Bayesian Analysis.

# %% [markdown]
# ## Additional Resources
# This section was pretty math heavy and included many new concepts like optimization, maximas and minimas, monotonicity, and log functions. With that, take some time to go through following resources to see more example of MLE calculation and get a deep dive into the underlying mathematical theory.
#
# * [Probability Concepts Explained: Maximum Likelihood Estimation](https://towardsdatascience.com/probability-concepts-explained-maximum-likelihood-estimation-c7b4342fdbb1) - Example for calculating MLE with normal distributions.
# * [IID Statistics: Independent and Identically Distributed ](https://www.statisticshowto.datasciencecentral.com/iid-statistics/)
# * [Monotonically Increasing and Decreasing function: An algebraic approach](https://opencurriculum.org/5512/monotonically-increasing-and-decreasing-functions-an-algebraic-approach/)
# * [Logarithm Functions](https://mathbitsnotebook.com/Algebra2/Exponential/EXLogFunctions.html)

# %% [markdown]
# ## Summary
#
# In this lesson, you began to develop an intuition surrounding MLE. You saw how to use the principle of monotonicity to simplify complex probability calculations into simple arithmetic operations. You also looked at a simple example of a coin toss for MLE. You're well on your way to conducting further complex statistical experiments using Bayesian techniques!
